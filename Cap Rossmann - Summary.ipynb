# %% [markdown]
# # Capstone Projekt Rossmann

# %% [markdown]
# # XDi - Certified Data Scientist
# # Christoph Gödecke

# %% [markdown]
# # Summary

# %% [markdown]
# ## 1 General task from the client
# - Determine the key factors that influence sales and revenue
# - Create strategies for the management to improve the business
#
# - Build a standardized forecasting model which can predict the sales figures for the next eight weeks for each store.
#
# - Generate a report with information on the overall performance of the 1115 stores as well as individual performance reports for each store.

# %% [markdown]
# ## 2 Key factors and interesting insights:

# %% [markdown]
# ### Impact of Promotions

# %% [markdown]
# ![Promotion Impact.png](attachment:c94e25a9-b139-4d46-a6b1-8026a036e580.png)

# %% [markdown]
# **Result:** The sales, customers and sales per customer are higher in weeks with promotions.
# - Sales per day is ~ 35% higher
# - Customers per day is ~ 19% higher
# - Sales per customer is ~ 13% higher
# - Stortype b is quite different. It just has 1/3 of the promotion impact.

# %% [markdown]
# **Result:** Also in a week with state holidays the promotions have a positive effect.
# - The sales per day is 38% higher
# - The customers per day is 20% higher
# - The sales per customer is 16% higher

# %% [markdown]
# ### Impact of Promo2

# %% [markdown]
# ![Promotion2 Impact.png](attachment:e924e6f7-fd43-4126-9810-e2eef2adba85.png)

# %% [markdown]
# **Result**: For Promo2 members, months with Promo2 has no significant impact
# - Sales per day is ~ 0.4% higher
# - Customers per day is the nearly the same as without Promo2
# - Sales per customer is ~ 0.4% higher

# %% [markdown]
# ### Performance of different assortments

# %% [markdown]
# ![Assortment a-b Impact.png](attachment:12aa9428-2249-4390-b039-3ed8d823ad94.png)

# %% [markdown]
# ![Assortment a-c Impact.png](attachment:37904f33-3114-471e-8123-b963f7d55538.png)

# %% [markdown]
# ![Assortment b-c Impact.png](attachment:7f99b6f7-2dab-4cf0-8112-4e4b23b24d19.png)

# %% [markdown]
# **Result**
# - Only Storetype b has the assortment caregory extra(b)
# - The sales per day in Storetype b for assortment extra(b) is 18% less then for assortment basic(a). They have 9.3% more customers but 34% less sales per customer.
# - The sales per day for assortment erweitert(c) is in average 26%(16%,81%,-2%,8%) higher then for assortment basic(a).
# - The sale per days for assortment erweitert(c) is 121% higher then for assortment extra(b).er.

# %% [markdown]
# ### Impact if competitor opens a store

# %% [markdown]
# ![Impact of opened competitor.png](attachment:ce9101a4-1e30-4fa8-98dc-c8de73d5c54d.png)

# %% [markdown]
# **Result:**
# - The sales is in average 5,5% less after the competeter has opened.

# %% [markdown]
# ### Saturday

# %% [markdown]
# ![image.png](attachment:435750fd-b7a6-4dea-b389-426abf23ff55.png)

# %% [markdown]
# **Result:**
# - The amount of customers on a Saturday is -22% lower then within the week.
# - The sales on a Saturday is ~ -20% lower then within the week.
# - The sales per customer on a Saturday is ~ 2% lower then within the week.

# %% [markdown]
# ### Impact of school holidays

# %% [markdown]
# ![Impact of school holidays.png](attachment:ccb0c41c-cd82-4e69-83aa-f33e41f2762a.png)

# %% [markdown]
# **Result:**
# - For Storetype a the sales on Schooldays are 1.3% lower.
# - For Storetype b the sales on Schooldays are 4.6% higher.
# - For Storetype c and d the sales on Schooldays are nearly the same higher with 0.7% and 0.9%.

# %% [markdown]
# ## 3 Improvement suggestions and ideas

# %% [markdown]
# - Stop Promo2 or change strategy
# - For storetype b try to open more stores with assortment erweitert(c)
# - For storetype a, d try to open more stores with assortment erweitert(c)
# - Try to stand out from the competitor and do special promotions on saturday for products relevant for the weekend.
# - On day with school holidays make special offers to this target group within storetype b.
# - Optimization of spend resources

# %% [markdown]
# ## 4 Sales Forecast

# %% [markdown]
# For the prediction of the sales for the next 8 weeks the libary Prophet is sugested. (With a MAE: 2595 and R2: 0.66 by calculating metrics for each store)

# %% [markdown]
# **Prophe:t** Forecast for store 836:

# %% [markdown]
# ![image.png](attachment:538f26f4-f3d5-428f-bae2-8b39b6582919.png)

# %% [markdown]
# ## 5 Reports

# %% [markdown]
# ### Store Report

# %% [markdown]
# ![image.png](attachment:8a79c489-97b8-4f85-9d53-bc7cc3dff2af.png)

# %% [markdown]
# #### Weekly

# %% [markdown]
# ![Store Report - Weekly.png](attachment:55b099bd-69ad-41e7-9228-9aabd1497665.png)

# %% [markdown]
# #### Monthly

# %% [markdown]
# ![Store Report - Monthly.png](attachment:655b9a20-cbe9-4ba5-9508-77118d0bece6.png)

# %% [markdown]
# ### Overall Report

# %% [markdown]
# ![image.png](attachment:b9720827-a6ab-4355-8400-44faede3213c.png)

# %% [markdown]
# ![Store Report - Monthly.png](attachment:c92922c6-fd12-4035-8ac3-9b004bb34aa5.png)
